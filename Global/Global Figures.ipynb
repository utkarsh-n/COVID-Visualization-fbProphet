# %%
# %store -r fig
# %store -r cases

# %%
fig.show()

# %%
death.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-19-3a7609da7bd6> in <module>
# ----> 1 death.show()
#
# AttributeError: 'NoneType' object has no attribute 'show'
